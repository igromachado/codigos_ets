# %%
import random
sum = 0

for i in range(500):
    sum += random.randint(1,6)
print(sum/1000)
# Out:
# 1.846

# %%
import random as r
import math as m

n = 10000
sum = 0

for i in range(n):
    sum += r.randint(5,21)
    
    if i > 7000:
        sum += r.randint(40,61)

print(sum/10000)
# Out:
# 28.1862
