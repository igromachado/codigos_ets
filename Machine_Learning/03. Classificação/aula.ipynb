# %%
from sklearn.naive_bayes import GaussianNB
import pickle
with open("../csv's/census.csv", 'rb') as f:
    X_census_treinamento, y_census_treinamento, X_census_teste, y_census_teste = pick
    
naive_census = GaussianNB()
naive_census.fit(X_census_treinamento.toarray(), y_census_treinamento)
previsoes = naive_census.predict(X_census_teste.toarray())
previsoes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 import pickle
#       3 with open("../csv's/census.csv", 'rb') as f:
# ----> 4     X_census_treinamento, y_census_treinamento, X_census_teste, y_census_teste = pick
#       6 naive_census = GaussianNB()
#       7 naive_census.fit(X_census_treinamento.toarray(), y_census_treinamento)
#
# NameError: name 'pick' is not defined
