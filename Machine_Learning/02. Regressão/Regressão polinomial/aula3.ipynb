# %% [markdown]
# transformação
# random tree = faz uma árvore com base em condicionais para classificar algo
# random forest = funciona como o random tree, mas utiliza parâmetros aleatórios para fazer sua classificação, tirando uma média no final
