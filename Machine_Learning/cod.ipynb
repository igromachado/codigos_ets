# %%
import plotly.express as px
 
grafico = px.scatter(x=aluno_y_teste, y=previsoes, labels={'x': 'Valor Real', 'y': 'Previsão do Modelo'})
 
grafico.add_scatter(x=aluno_y_teste, y=aluno_y_teste, name='Regressão (Ideal)', mode='lines')
 
grafico.update_layout(title_text="Regressão Múltipla", title_x=0.5)
 
grafico.show()

# %%
import plotly.express as px
 
# 1. Cria o gráfico de dispersão com os valores REAIS no X e as PREVISÕES no Y
grafico = px.scatter(x=Y_INPC_teste, y=previsoes,
    labels={'x': 'Valor Real (INPC)', 'y': 'Previsão do Modelo'}
)
 
# 2. Adiciona a linha de tendência/regressão ideal ao gráfico
grafico.add_scatter(x=Y_INPC_teste, y=Y_INPC_teste,
    name='Regressão (Ideal)',
    mode='lines'
)
 
# 3. Exibe o gráfico interativo
grafico.show()
