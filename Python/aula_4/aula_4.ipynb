# %% [markdown]
# EXERCÍCIO 1 - Crie uma função "bhaskara()", que recebe a,b,c, e retorna os dois resultados possíveis da equação de bhasakara (retorna "i", caso dê um número imaginário)

# %%
def bhaskara(a,b,c):
    
    delta = (b**2)- (4 * a * c)
    if delta < 0:
        return "i"
    
    delta = delta**0.5
    
    return (
        (-b + (delta)) / (2 * a),
        (-b - (delta)) / (2 * a)
    )

r = bhaskara(2,4,-6) # esperado -> (1.0, -3.0)
print(r)
# Out:
# (1.0, -3.0)

# %% [markdown]
# EXERCÍCIO 2 - Crie uma função "toLow()" que recebe uma string e retorna uma  versão dessa string com todos os caracteres minusculos (caracteres especiais devem ser mantidos)

# %%
def toLow(a):
    
    seila = '' #string vazia, é possível adicionar caracteres nela mesma
    
    for letra in a:
        codigos = ord(letra)
        
        if codigos >= 65 and codigos <= 90: 
            codigos = codigos + 32
            seila += chr(codigos)
            
        else:
            seila += chr(codigos)
    
    resultado = seila
    
    return resultado
    
a = ('HaHA PaPOi? HAHA PAPOI! UaaaaA')
print(toLow(a))
# Out:
# haha papoi? haha papoi! uaaaaa

# %% [markdown]
# EXERCICIO 3 - # Crie uma função "sort()" que recebe uma lista, ordena ela do menor para o maior e retorna ela ordenada

# %%
def sort():
    
    a = [7,5,10,1,9]
    
    for i in range(len(a)):
    
        for j in range(len(a)):
            
            if a[j] > a[i]:
                guardado = a[j]
                a[j] = a[i]
                a[i] = guardado
                
    return a
                
a = sort()

print(a)
# Out:
# [1, 5, 7, 9, 10]
