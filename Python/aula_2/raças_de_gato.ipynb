# %%
arquivo = {}


with open('./cat_breeds.csv', 'r') as gatos:
    colunas = gatos.readline().split(';')
    for i in range(len(colunas)):
       valores = gatos.readline().split(';')
       
       for j in range(len(valores)):
           arquivo[colunas[i]] = valores[i]

print(arquivo)
# Out:
# {'ï»¿Breed': 'Angora', 'Age_in_years': '0.33', 'Age_in_months': '6', 'Gender': 'female', 'Neutered_or_spayed': 'FALSE', 'Body_length': '21', 'Weight': '3', 'Fur_colour_dominant': 'red/cream', 'Fur_pattern': 'tortie', 'Eye_colour': 'blue', 'Allowed_outdoor': 'FALSE', 'Preferred_food': 'wet', 'Owner_play_time_minutes': '46', 'Sleep_time_hours': '14', 'Country': 'France', 'Latitude': '48.864716', 'Longitude\n': '-1.553621\n'}
