# %%
import time
import os

# %%
path = os.path.abspath('')
teste = os.path.abspath('pasta_teste')
nova = os.path.abspath('nova_pasta')

arquivos = os.listdir()

for i in arquivos:
    os.path.isdir('')
    print(i)
# Out:
# True
# desafio.ipynb
# True
# nova_pasta
# True
# NumPy 1.pdf
# True
# NumPy 2.pdf
# True
# NumPy.pdf
# True
# pasta_teste
